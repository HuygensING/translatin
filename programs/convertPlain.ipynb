# %% [markdown]
# # Convert from DOCX to TEI to TF to WATM
#
# We convert DOCX to TEI to TF and then to WATM.
#
# This notebook provides three levels of refinement in the execution. They all have the same outcome,
# but they differ in the level of detail they provide on the conversion.
#
# These are the levels:
#
# * **Debugging**: all the commands directly in Python, the intermediate data remains in memory and can  be inspected.
# * **Step by step**: one command for each main step of the conversion;
# * **Express**: one single command on the command line for the complete conversion;

# %% [markdown]
# # Production or development
#
# Mosts steps are unaffected by the production/development setting.
#
# In the first steps of the pipeline (*ingest* and *scan processing*) we prepare both the dev and the prod data.
#
# The intermediate steps (*from DOCX to TEI*, *from TEI to TF*, *mark named entities*) are identical for prod and dev.
#
# Only for the latter steps (*convert TF to WATM*, generate IIIF manifests*, *deploy to k8s*) there is a distinction between prod and dev.
#
# For these steps we have commented out the line that does the dev version.

# %% [markdown]
# # Requirements
#
# * zsh as command line shell (as in macOS);
# * access to suitable k8s clusters, streamlined by the
#   [k-suite](https://code.huc.knaw.nl/tt/smart-k8s/-/blob/main/docs/k-suite.md);
# * [Pandoc](https://pandoc.org)
# * [Python](https://www.python.org) (3.12 or higher) with additional pip-installable modules:
#   * text-fabric
#   * openpyxl

# %% [markdown]
# # Declare the version
#
# Always set the version before running any cell in this notebook!

# %%
VERSION = "0.0.1"

# %% [markdown]
# # In debugging mode.
#
# Now we dig a bit deeper, en do all the steps while keeping the program in memory.
# Now it becomes doable to inspect all intermediate results.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tf.app import use
from tf.convert.tei import TEI
from tf.convert.watm import WATM
from tf.advanced.helpers import dm

from processdocs import TeiFromDocx
from processhelpers import SOURCEBASE, REPORT_TEIDIR

# %% [markdown]
# ## Step 1: From DOCX to TEI

# %% [markdown]
# You might need to do
#
# ```
# pip install docx2python
# ```

# %%
TFD = TeiFromDocx(silent=False)
# Out:
# GET docx files and their metadata from XLS ...
#
# Collecting excel metadata ...
# Metadata collected.
# 0 warnings
# Continuing with 118 good files among 118 in total
# 0 informational messages
# 0 warnings

# %%
TFD.task("convert", forceClean=True, skipTeix=True, skipTei=True, workName="Honerdus-Thamara")
# Out:
# DOCX => Markdown per work ...
# 	   work                           |   lines | lnums | pages | folios| sect | conversion steps
# 	OK Honerdus-Thamara               |    3205 |   272 |    56 |    13 |   16 | clean special
# 	OK All works (1)                  |    3205 |   272 |    56 |    13 |   16 | done
# Works without specifics defined: 0
# See for pages: ~/github/HuygensING/translatin/report/trans/lines.yml
# See for pages: ~/github/HuygensING/translatin/report/trans/pages.yml
# See for sections: ~/github/HuygensING/translatin/report/trans/sections.yml
# 0 informational messages
# 0 warnings

# %%
TFD.task("convert", forceClean=True, skipTeix=True, skipTei=True)
# Out:
# DOCX => Markdown per work ...
# 	   work                           |   lines | lnums | pages | folios| sect | conversion steps
# 	OK Alberti-Philodoxus             |     891 |     0 |    38 |     0 |   23 | clean special
# 	OK Aler-Innocentia                |    2755 |     0 |    40 |     0 |   36 | clean special
# 	OK Balde-Iephtias                 |    9861 |     0 |     0 |     0 |   72 | clean generic
# 	OK Barlandus-Dialogus             |      95 |     0 |     0 |     0 |    0 | clean generic
# 	OK Beza-Abrahamus                 |    3137 |     0 |    46 |     0 |    9 | clean special
# 	OK Brechtus-Euripus               |    6155 |   470 |   112 |    94 |   13 | clean special
# 	OK Caussin-Felicitas              |    4235 |     0 |     0 |     0 |   23 | clean generic
# 	OK Caussin-Hermenigildus          |    1145 |     0 |   101 |     0 |    7 | clean special
# 	OK Caussin-Nabuchodonosor         |    3351 |     0 |     0 |     0 |   15 | clean generic
# 	OK Caussin-Solyma                 |    3829 |     0 |     0 |     0 |   17 | clean generic
# 	OK Caussin-Theodoricus            |    3359 |     0 |     0 |     0 |   12 | clean generic
# 	OK Cellotius-Adrianus             |    5871 |     0 |   103 |     0 |   40 | clean special
# 	OK Cellotius-Chosroes             |    4151 |     0 |    81 |     0 |   39 | clean special
# 	OK Cellotius-Reviviscentes        |    4681 |     0 |   112 |     0 |   52 | clean special
# 	OK Cellotius-Sapor                |    6857 |     0 |   137 |     0 |   62 | clean special
# 	OK Celtis-Ludus                   |     569 |     0 |     0 |     0 |    5 | clean generic
# 	OK Claus-Vulpanser                |    1451 |   127 |     0 |     0 |   37 | clean generic
# 	OK Crocus-Ioseph                  |    2125 |   165 |     0 |     0 |   20 | clean generic
# 	OK Cunaeus-Dido                   |    1813 |   180 |     0 |     0 |    5 | clean generic
# 	OK Dalanthus-Dido                 |    5379 |   490 |    82 |    19 |   29 | clean special
# 	OK Diether-Ioseph                 |    6007 |     0 |     0 |     0 |   37 | clean generic
# 	OK Enden-Philedonius              |    2403 |   197 |     0 |    40 |   25 | clean special
# 	OK Ens-Auriacus                   |    2305 |     0 |     0 |     0 |   14 | clean generic
# 	OK Forsett-Pedantius              |    3133 |     0 |   173 |     0 |   32 | clean special
# 	OK Foxe-Christus                  |    5661 |     0 |   120 |     0 |   41 | clean special
# 	OK Gnapheus-Acolastus             |    4845 |     0 |     0 |     0 |   30 | clean generic
# 	OK Gnapheus-Morosophus            |    3217 |     0 |     0 |     0 |   26 | clean generic
# 	OK Goethals-Soter                 |    3591 |   301 |    63 |    16 |   38 | clean special
# 	OK Gretser-Timon                  |     393 |    15 |     0 |     0 |    3 | clean generic
# 	OK Gretser-Underwaldius           |     589 |    16 |     0 |     0 |    3 | clean generic
# 	OK Grimald-Christus               |    3395 |   317 |     0 |     0 |   29 | clean generic
# 	OK Grotius-Adamus                 |    4233 |   407 |     0 |     0 |    9 | clean generic
# 	OK Grotius-Christus               |    3019 |   285 |     0 |     0 |   16 | clean generic
# 	OK Grotius-Phoenissae             |    4187 |   359 |   127 |    44 |   24 | clean special
# 	OK Gwalther-Nabal                 |    4443 |     0 |     0 |     0 |   57 | clean generic
# 	OK Heinsius-Auriacus              |    4445 |     0 |     0 |     0 |   16 | clean generic
# 	OK Heinsius-Herodes               |    4187 |    17 |    14 |   110 |   10 | clean special
# 	OK Holonius-Catharina             |    3683 |   323 |    78 |    18 |   85 | clean special
# 	OK Holonius-Laurentias            |    3245 |   277 |    69 |    17 |   76 | clean special
# 	OK Honerdus-Thamara               |    3205 |   272 |    56 |    13 |   16 | clean special
# 	OK Houcharius-Grisellis           |    9449 |   514 |     0 |     0 |    4 | clean
# 	OK Houthem-Gedeon                 |    2697 |   192 |     0 |     0 |   27 | clean
# 	OK Ischyrius-Homulus              |    4292 |   313 |     0 |     0 |   29 | clean
# 	OK Kerckmeister-Codrus            |    1325 |     2 |     0 |     0 |    2 | clean
# 	OK Knuyt-Scornetta                |    1025 |    94 |     0 |     0 |    0 | clean
# 	OK Laurimanus-Exodus              |    7785 |   632 |    53 |     0 |   68 | clean special
# 	OK Laurimanus-Miles               |    6937 |   558 |    59 |     0 |   49 | clean special
# 	OK Locher-Iudicium                |    1411 |   109 |     0 |     0 |    3 | clean
# 	OK Lummenaeus-Abimelech           |    1531 |   130 |     0 |     0 |   10 | clean
# 	OK Lummenaeus-Amnon               |    2461 |   226 |     0 |     0 |   27 | clean
# 	OK Lummenaeus-Bustum              |    1753 |   160 |     0 |     0 |   10 | clean
# 	OK Lummenaeus-Carcer              |    2821 |   234 |     0 |     0 |   13 | clean
# 	OK Lummenaeus-Iephte              |    1483 |   117 |     0 |     0 |    8 | clean
# 	OK Lummenaeus-Sampson             |    1517 |   129 |     0 |     0 |    9 | clean
# 	OK Lummenaeus-Saul                |    1931 |   164 |     0 |     0 |   10 | clean
# 	OK Macropedius-Adamus             |    5887 |     2 |     0 |     0 |   65 | clean
# 	OK Macropedius-Aluta              |    1313 |     0 |     0 |     0 |   26 | clean
# 	OK Macropedius-Andrisca           |    2775 |   243 |     0 |     0 |   35 | clean
# 	OK Macropedius-Asotus             |    4087 |     0 |     0 |     0 |   44 | clean
# 	OK Macropedius-Bassarus           |    2293 |     0 |     0 |     0 |   34 | clean
# 	OK Macropedius-Hecastus           |    4471 |     0 |     0 |     0 |   45 | clean
# 	OK Macropedius-Hypomone           |    2731 |     0 |     0 |     0 |   27 | clean
# 	OK Macropedius-Iesus              |    2597 |     0 |     0 |     0 |   48 | clean
# 	OK Macropedius-Iosephus           |    4449 |     3 |     0 |     0 |   49 | clean
# 	OK Macropedius-Lazarus            |    3175 |     1 |     0 |     0 |   39 | clean
# 	OK Macropedius-Petriscus          |    3237 |     0 |     0 |     0 |   44 | clean
# 	OK Macropedius-Rebelles           |    2539 |     0 |     0 |     0 |   45 | clean
# 	OK Malapertius-Sedecias           |    3425 |   333 |     0 |     0 |   12 | clean
# 	OK Muretus-Caesar                 |    1279 |     0 |     0 |     0 |   13 | clean
# 	OK Mussato-Ecerinis               |    1331 |   126 |     0 |     0 |   23 | clean
# 	OK Narssius-Gustavus              |    3543 |   332 |     0 |     0 |    9 | clean
# 	OK Papaeus-Samarites              |    2125 |   184 |     0 |     0 |   27 | clean
# 	OK Philicinus-Esther              |    4209 |     1 |     0 |     0 |   27 | clean
# 	OK Philicinus-Magdalena           |    4649 |    26 |     0 |     0 |   28 | clean
# 	OK Placentius-Clericus            |     443 |    44 |     0 |     0 |    0 | clean
# 	OK Placentius-Plausus             |     459 |    35 |     0 |     0 |    1 | clean
# 	OK Placentius-Susanna             |    1089 |     0 |     0 |     0 |    4 | clean
# 	OK Reuchlin-Henno                 |    1011 |    87 |     0 |     0 |    8 | clean
# 	OK Reuchlin-Sergius               |    1129 |    99 |     0 |     0 |    9 | clean
# 	OK Rosefeldus-Moschus             |    5049 |     0 |     0 |     0 |   31 | clean
# 	OK Roulerius-Stuarta              |    3675 |   314 |     0 |     0 |   14 | clean
# 	OK Ruggle-Ignoramus               |    7953 |   743 |     0 |     0 |   60 | clean
# 	OK Salius-Nassovius               |    1781 |   150 |     0 |     0 |   14 | clean
# 	OK Schonaeus-Ananias              |    2965 |   240 |     0 |     0 |   24 | clean
# 	OK Schonaeus-Baptistes            |    2657 |   218 |     0 |     0 |   28 | clean
# 	OK Schonaeus-Cunae                |    2197 |   175 |     0 |     0 |   20 | clean
# 	OK Schonaeus-Daniel               |    2769 |   226 |     0 |     0 |   25 | clean
# 	OK Schonaeus-Dyscoli              |    2097 |   169 |     0 |     0 |   22 | clean
# 	OK Schonaeus-Fabula               |    2145 |     1 |     0 |     0 |   20 | clean
# 	OK Schonaeus-Iosephus             |    4107 |   338 |     0 |     0 |   33 | clean
# 	OK Schonaeus-Iuditha              |    4059 |   221 |     0 |     0 |   30 | clean
# 	OK Schonaeus-Naaman               |    3995 |   318 |     0 |     0 |   30 | clean
# 	OK Schonaeus-Nehemias             |    3317 |   279 |     0 |     0 |   30 | clean
# 	OK Schonaeus-Pentecoste           |    2771 |   223 |     0 |     0 |   22 | clean
# 	OK Schonaeus-Pseudostratiotae     |    2229 |   179 |     0 |     0 |   22 | clean
# 	OK Schonaeus-Saulus               |    3963 |   326 |     0 |     0 |   29 | clean
# 	OK Schonaeus-Susanna              |    2963 |   248 |     0 |     0 |   25 | clean
# 	OK Schonaeus-Tobaeus              |    4183 |   350 |     0 |     0 |   39 | clean
# 	OK Schonaeus-Triumphus            |    2613 |   214 |     0 |     0 |   20 | clean
# 	OK Schonaeus-Typhlus              |    2631 |   208 |     0 |     0 |   23 | clean
# 	OK Schonaeus-Vitulus              |    2175 |   180 |     0 |     0 |   23 | clean
# 	OK Schopper-Ectrachelistes        |    5181 |     0 |     0 |     0 |   20 | clean
# 	OK Simonides-Castus               |    3917 |   351 |     0 |     0 |   15 | clean
# 	OK Stymmelius-Isaac               |    3541 |    53 |     0 |     0 |   34 | clean
# 	OK Stymmelius-Studentes           |    3321 |     0 |     0 |     0 |   27 | clean
# 	OK Susius-Pendularia              |    1843 |   150 |     0 |     0 |   20 | clean
# 	OK Telesio-Imber                  |    2717 |   219 |     0 |     0 |   21 | clean
# 	OK Vernulaeus-Conradinus          |    4569 |   404 |     0 |     0 |   36 | clean
# 	OK Vernulaeus-Crispus             |    3217 |   286 |     0 |     0 |   35 | clean
# 	OK Vernulaeus-Gorcomienses        |    5377 |   450 |     0 |     0 |   35 | clean
# 	OK Vernulaeus-Henricus            |    5127 |     0 |     0 |     0 |   52 | clean
# 	OK Vernulaeus-Theodoricus         |    4355 |   380 |     0 |     0 |   54 | clean
# 	OK Vladeraccus-Tobias             |    3775 |   299 |     0 |     0 |   54 | clean
# 	OK Weitenauer-Annibal             |    3659 |   329 |     0 |     0 |   46 | clean
# 	OK Wimpheling-Stylpho             |     217 |     0 |     0 |     0 |    8 | clean
# 	OK Zevecotius-Rosimunda           |    2667 |   215 |     0 |     0 |   10 | clean
# 	OK Zovitius-Didascalus            |    1627 |     0 |     0 |     0 |   17 | clean
# 	OK Zovitius-Ruth                  |    3709 |     0 |     0 |     0 |   24 | clean
# 	OK All works (118)                |  385673 | 17764 |  1664 |   371 | 3126 | done
# Works without specifics defined: 76
# See for pages: ~/github/HuygensING/translatin/report/trans/lines.yml
# See for pages: ~/github/HuygensING/translatin/report/trans/pages.yml
# See for sections: ~/github/HuygensING/translatin/report/trans/sections.yml
# 0 informational messages
# 0 warnings

# %%
TFD.task("convert")
# Out:
# DOCX => Markdown per work ...
# 	   work                           |   lines | lnums | pages | folios| sect | conversion steps
# 	OK Alberti-Philodoxus             |     891 |     0 |    38 |     0 |   23 | teisimple tei
# 	OK Aler-Innocentia                |    2755 |     0 |    40 |     0 |   36 | teisimple tei
# 	OK Balde-Iephtias                 |    9861 |     0 |     0 |     0 |   72 | teisimple tei
# 	OK Barlandus-Dialogus             |      95 |     0 |     0 |     0 |    0 | teisimple tei
# 	OK Beza-Abrahamus                 |    3137 |     0 |    46 |     0 |    9 | teisimple tei
# 	OK Brechtus-Euripus               |    6155 |   470 |   112 |    94 |   13 | teisimple tei
# 	OK Caussin-Felicitas              |    4235 |     0 |     0 |     0 |   23 | teisimple tei
# 	OK Caussin-Hermenigildus          |    1145 |     0 |   101 |     0 |    7 | teisimple tei
# 	OK Caussin-Nabuchodonosor         |    3351 |     0 |     0 |     0 |   15 | teisimple tei
# 	OK Caussin-Solyma                 |    3829 |     0 |     0 |     0 |   17 | teisimple tei
# 	OK Caussin-Theodoricus            |    3359 |     0 |     0 |     0 |   12 | teisimple tei
# 	OK Cellotius-Adrianus             |    5871 |     0 |   103 |     0 |   40 | teisimple tei
# 	OK Cellotius-Chosroes             |    4151 |     0 |    81 |     0 |   39 | teisimple tei
# 	OK Cellotius-Reviviscentes        |    4681 |     0 |   112 |     0 |   52 | teisimple tei
# 	OK Cellotius-Sapor                |    6857 |     0 |   137 |     0 |   62 | teisimple tei
# 	OK Celtis-Ludus                   |     569 |     0 |     0 |     0 |    5 | teisimple tei
# 	OK Claus-Vulpanser                |    1451 |   127 |     0 |     0 |   37 | teisimple tei
# 	OK Crocus-Ioseph                  |    2125 |   165 |     0 |     0 |   20 | teisimple tei
# 	OK Cunaeus-Dido                   |    1813 |   180 |     0 |     0 |    5 | teisimple tei
# 	OK Dalanthus-Dido                 |    5379 |   490 |    82 |    19 |   29 | teisimple tei
# 	OK Diether-Ioseph                 |    6007 |     0 |     0 |     0 |   37 | teisimple tei
# 	OK Enden-Philedonius              |    2403 |   197 |     0 |    40 |   25 | teisimple tei
# 	OK Ens-Auriacus                   |    2305 |     0 |     0 |     0 |   14 | teisimple tei
# 	OK Forsett-Pedantius              |    3133 |     0 |   173 |     0 |   32 | teisimple tei
# 	OK Foxe-Christus                  |    5661 |     0 |   120 |     0 |   41 | teisimple tei
# 	OK Gnapheus-Acolastus             |    4845 |     0 |     0 |     0 |   30 | teisimple tei
# 	OK Gnapheus-Morosophus            |    3217 |     0 |     0 |     0 |   26 | teisimple tei
# 	OK Goethals-Soter                 |    3591 |   301 |    63 |    16 |   37 | teisimple tei
# 	OK Gretser-Timon                  |     393 |    15 |     0 |     0 |    3 | teisimple tei
# 	OK Gretser-Underwaldius           |     589 |    16 |     0 |     0 |    3 | teisimple tei
# 	OK Grimald-Christus               |    3395 |   317 |     0 |     0 |   29 | teisimple tei
# 	OK Grotius-Adamus                 |    4640 |   407 |     0 |     0 |    9 | teisimple tei
# 	OK Grotius-Christus               |    3304 |   285 |     0 |     0 |   16 | teisimple tei
# 	OK Grotius-Phoenissae             |    4125 |   359 |     0 |     0 |   24 | teisimple tei
# 	OK Gwalther-Nabal                 |    4443 |     0 |     0 |     0 |   57 | teisimple tei
# 	OK Heinsius-Auriacus              |    4445 |     0 |     0 |     0 |   15 | teisimple tei
# 	OK Heinsius-Herodes               |    4187 |    17 |     0 |     0 |    8 | teisimple tei
# 	OK Holonius-Catharina             |    3683 |   323 |     0 |     0 |   51 | teisimple tei
# 	OK Holonius-Laurentias            |    3245 |   277 |     0 |     0 |   74 | teisimple tei
# 	OK Honerdus-Thamara               |    3205 |   272 |     0 |     0 |   13 | teisimple tei
# 	OK Houcharius-Grisellis           |    9449 |   514 |     0 |     0 |    4 | teisimple tei
# 	OK Houthem-Gedeon                 |    2888 |   192 |     0 |     0 |   27 | teisimple tei
# 	OK Ischyrius-Homulus              |    4594 |   313 |     0 |     0 |   29 | teisimple tei
# 	OK Kerckmeister-Codrus            |    1327 |     2 |     0 |     0 |    2 | teisimple tei
# 	OK Knuyt-Scornetta                |    1114 |    94 |     0 |     0 |    0 | teisimple tei
# 	OK Laurimanus-Exodus              |    8413 |   632 |    53 |     0 |   68 | teisimple tei
# 	OK Laurimanus-Miles               |    6937 |   558 |    59 |     0 |   49 | teisimple tei
# 	OK Locher-Iudicium                |    1411 |   109 |     0 |     0 |    3 | teisimple tei
# 	OK Lummenaeus-Abimelech           |    1660 |   130 |     0 |     0 |   10 | teisimple tei
# 	OK Lummenaeus-Amnon               |    2461 |   226 |     0 |     0 |   27 | teisimple tei
# 	OK Lummenaeus-Bustum              |    1912 |   160 |     0 |     0 |   10 | teisimple tei
# 	OK Lummenaeus-Carcer              |    2821 |   234 |     0 |     0 |   13 | teisimple tei
# 	OK Lummenaeus-Iephte              |    1600 |   117 |     0 |     0 |    8 | teisimple tei
# 	OK Lummenaeus-Sampson             |    1646 |   129 |     0 |     0 |    9 | teisimple tei
# 	OK Lummenaeus-Saul                |    2095 |   164 |     0 |     0 |   10 | teisimple tei
# 	OK Macropedius-Adamus             |    5887 |     2 |     0 |     0 |   65 | teisimple tei
# 	OK Macropedius-Aluta              |    1313 |     0 |     0 |     0 |   26 | teisimple tei
# 	OK Macropedius-Andrisca           |    2775 |   243 |     0 |     0 |   35 | teisimple tei
# 	OK Macropedius-Asotus             |    4087 |     0 |     0 |     0 |   44 | teisimple tei
# 	OK Macropedius-Bassarus           |    2293 |     0 |     0 |     0 |   34 | teisimple tei
# 	OK Macropedius-Hecastus           |    4471 |     0 |     0 |     0 |   45 | teisimple tei
# 	OK Macropedius-Hypomone           |    2731 |     0 |     0 |     0 |   27 | teisimple tei
# 	OK Macropedius-Iesus              |    2597 |     0 |     0 |     0 |   48 | teisimple tei
# 	OK Macropedius-Iosephus           |    4449 |     3 |     0 |     0 |   49 | teisimple tei
# 	OK Macropedius-Lazarus            |    3175 |     1 |     0 |     0 |   39 | teisimple tei
# 	OK Macropedius-Petriscus          |    3237 |     0 |     0 |     0 |   44 | teisimple tei
# 	OK Macropedius-Rebelles           |    2539 |     0 |     0 |     0 |   45 | teisimple tei
# 	OK Malapertius-Sedecias           |    3425 |   333 |     0 |     0 |   12 | teisimple tei
# 	OK Muretus-Caesar                 |    1279 |     0 |     0 |     0 |   13 | teisimple tei
# 	OK Mussato-Ecerinis               |    1331 |   126 |     0 |     0 |   23 | teisimple tei
# 	OK Narssius-Gustavus              |    3829 |   332 |     0 |     0 |    9 | teisimple tei
# 	OK Papaeus-Samarites              |    2125 |   184 |     0 |     0 |   27 | teisimple tei
# 	OK Philicinus-Esther              |    4209 |     1 |     0 |     0 |   27 | teisimple tei
# 	OK Philicinus-Magdalena           |    4661 |    26 |     0 |     0 |   28 | teisimple tei
# 	OK Placentius-Clericus            |     487 |    44 |     0 |     0 |    0 | teisimple tei
# 	OK Placentius-Plausus             |     459 |    35 |     0 |     0 |    1 | teisimple tei
# 	OK Placentius-Susanna             |    1089 |     0 |     0 |     0 |    4 | teisimple tei
# 	OK Reuchlin-Henno                 |    1011 |    87 |     0 |     0 |    8 | teisimple tei
# 	OK Reuchlin-Sergius               |    1130 |    99 |     0 |     0 |    9 | teisimple tei
# 	OK Rosefeldus-Moschus             |    5049 |     0 |     0 |     0 |   31 | teisimple tei
# 	OK Roulerius-Stuarta              |    3675 |   314 |     0 |     0 |   14 | teisimple tei
# 	OK Ruggle-Ignoramus               |    7953 |   743 |     0 |     0 |   56 | teisimple tei
# 	OK Salius-Nassovius               |    1931 |   150 |     0 |     0 |   14 | teisimple tei
# 	OK Schonaeus-Ananias              |    2965 |   240 |     0 |     0 |   24 | teisimple tei
# 	OK Schonaeus-Baptistes            |    2657 |   218 |     0 |     0 |   28 | teisimple tei
# 	OK Schonaeus-Cunae                |    2197 |   175 |     0 |     0 |   20 | teisimple tei
# 	OK Schonaeus-Daniel               |    2769 |   226 |     0 |     0 |   25 | teisimple tei
# 	OK Schonaeus-Dyscoli              |    2097 |   169 |     0 |     0 |   22 | teisimple tei
# 	OK Schonaeus-Fabula               |    2145 |     1 |     0 |     0 |   20 | teisimple tei
# 	OK Schonaeus-Iosephus             |    4107 |   338 |     0 |     0 |   33 | teisimple tei
# 	OK Schonaeus-Iuditha              |    4059 |   221 |     0 |     0 |   30 | teisimple tei
# 	OK Schonaeus-Naaman               |    3995 |   318 |     0 |     0 |   30 | teisimple tei
# 	OK Schonaeus-Nehemias             |    3317 |   279 |     0 |     0 |   30 | teisimple tei
# 	OK Schonaeus-Pentecoste           |    2771 |   223 |     0 |     0 |   22 | teisimple tei
# 	OK Schonaeus-Pseudostratiotae     |    2229 |   179 |     0 |     0 |   22 | teisimple tei
# 	OK Schonaeus-Saulus               |    3963 |   326 |     0 |     0 |   29 | teisimple tei
# 	OK Schonaeus-Susanna              |    2963 |   248 |     0 |     0 |   25 | teisimple tei
# 	OK Schonaeus-Tobaeus              |    4183 |   350 |     0 |     0 |   39 | teisimple tei
# 	OK Schonaeus-Triumphus            |    2613 |   214 |     0 |     0 |   20 | teisimple tei
# 	OK Schonaeus-Typhlus              |    2631 |   208 |     0 |     0 |   23 | teisimple tei
# 	OK Schonaeus-Vitulus              |    2175 |   180 |     0 |     0 |   23 | teisimple tei
# 	OK Schopper-Ectrachelistes        |    5181 |     0 |     0 |     0 |   20 | teisimple tei
# 	OK Simonides-Castus               |    4268 |   351 |     0 |     0 |   15 | teisimple tei
# 	OK Stymmelius-Isaac               |    3541 |    53 |     0 |     0 |   34 | teisimple tei
# 	OK Stymmelius-Studentes           |    3321 |     0 |     0 |     0 |   27 | teisimple tei
# 	OK Susius-Pendularia              |    1993 |   150 |     0 |     0 |   20 | teisimple tei
# 	OK Telesio-Imber                  |    2717 |   219 |     0 |     0 |   21 | teisimple tei
# 	OK Vernulaeus-Conradinus          |    4973 |   404 |     0 |     0 |   36 | teisimple tei
# 	OK Vernulaeus-Crispus             |    3501 |   286 |     0 |     0 |   35 | teisimple tei
# 	OK Vernulaeus-Gorcomienses        |    5377 |   450 |     0 |     0 |   35 | teisimple tei
# 	OK Vernulaeus-Henricus            |    5127 |     0 |     0 |     0 |   52 | teisimple tei
# 	OK Vernulaeus-Theodoricus         |    4733 |   380 |     0 |     0 |   54 | teisimple tei
# 	OK Vladeraccus-Tobias             |    3781 |   299 |     0 |     0 |   54 | teisimple tei
# 	OK Weitenauer-Annibal             |    3660 |   329 |     0 |     0 |   46 | teisimple tei
# 	OK Wimpheling-Stylpho             |     217 |     0 |     0 |     0 |    8 | teisimple tei
# 	OK Zevecotius-Rosimunda           |    2667 |   215 |     0 |     0 |   10 | teisimple tei
# 	OK Zovitius-Didascalus            |    1627 |     0 |     0 |     0 |   17 | teisimple tei
# 	OK Zovitius-Ruth                  |    3709 |     0 |     0 |     0 |   24 | teisimple tei
# 	OK All works (118)                |  390280 | 17764 |  1320 |   169 | 3079 | done
# Works without specifics defined: 0
# 0 informational messages
# 0 warnings

# %% [markdown]
# ## Step 4: From TEI to TF
#
# ### Check the validity of the TEI.

# %%
Tei = TEI(verbose=-1, sourceBase=SOURCEBASE, reportDir=REPORT_TEIDIR, tei="", tf=VERSION)

# %%
# validate = 1
validate = True
Tei.task(check=True, verbose=1, validate=validate)
# Out:
# TEI to TF checking: ~/github/HuygensING/translatin/datasource/tei => ~/github/HuygensING/translatin/report/tei
# Processing instructions are ignored
# XML validation will be performed
# Analysing ~/github/annotation/text-fabric/tf/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/annotation/text-fabric/tf/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/HuygensING/translatin/datasource/schema/translatin.xsd
# Warning: tei:tei_model.frontPart.kind is not defined.
# 	round   1:  49 changes
# Warning: tei:tei_model.frontPart.kind is not defined.
#  91 identical override(s)
#   0 changing override(s)
# Section model III
# 	   1 translatin                             Alberti-Philodoxus.xml
# 	   2 translatin                             Aler-Innocentia.xml
# 	   3 translatin                             Balde-Iephtias.xml
# 	   4 translatin                             Barlandus-Dialogus.xml
# 	   5 translatin                             Beza-Abrahamus.xml
#
# 118 translatin file(s) ...
# 	Validating ...
# 	Making inventory ...
#
# 584 tag(s) type info written to ~/github/HuygensING/translatin/report/tei/types.txt
# Validation OK
# 36 tags of which 0 with multiple namespaces written to ~/github/HuygensING/translatin/report/tei/namespaces.txt
# 495 info line(s) written to ~/github/HuygensING/translatin/report/tei/elements.txt
# Refs written to ~/github/HuygensING/translatin/report/tei/refs.txt
# 	resolvable: 3109 in 3109
# 	dangling:      1 in    1
# 	ALL:        3110 in 3110
# Ids written to ~/github/HuygensING/translatin/report/tei/ids.txt
# 	referenced: 3109 by 3109
# 	non-unique:    0
# 	unused:     3062
# 	ALL:        6171 in 6171
# lb-parent info written to ~/github/HuygensING/translatin/report/tei/lb-parents.txt
# True

# %% [markdown]
# ### Convert the data

# %%
Tei.good = True
Tei.task(convert=True, verbose=0)
# Out:
# Line model II with ln nodes for lines between lb elements
# Page model II with page nodes for pages started by pb elements  keeping the pb elements
# Section model III
# Processing instructions are ignored
# Analysing ~/github/annotation/text-fabric/tf/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/annotation/text-fabric/tf/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/HuygensING/translatin/datasource/schema/translatin.xsd
# Warning: tei:tei_model.frontPart.kind is not defined.
# 	round   1:  49 changes
# Warning: tei:tei_model.frontPart.kind is not defined.
#  91 identical override(s)
#   0 changing override(s)
#   0.00s Importing data from walking through the source ...
#    |     0.00s Preparing metadata...
#    |     0.00s OK
#    |     0.00s Following director...
# 		   1 translatin                             Alberti-Philodoxus.xml
# 		   2 translatin                             Aler-Innocentia.xml
# 		   3 translatin                             Balde-Iephtias.xml
# 		   4 translatin                             Barlandus-Dialogus.xml
# 		   5 translatin                             Beza-Abrahamus.xml
#
# Resolving links into edges ...
# 	3109 in 3109 reference(s) resolved
# 	1 in 1 reference(s): could not be resolved
#    |       10s "delete" actions: 0
#    |       10s "edge" actions: 3109
#    |       10s "feature" actions: 2166034
#    |       10s "node" actions: 420384
#    |       10s "resume" actions: 0
#    |       10s "slot" actions: 1658296
#    |       10s "terminate" actions: 420502
#    |    2078680 nodes of all types
#    |       10s OK
#    |     0.00s checking for nodes and edges ...
#    |     0.00s OK
#    |     0.00s checking (section) features ...
#    |     0.06s OK
#    |     0.00s reordering nodes ...
#    |     0.98s Max node = 2078680
#    |     0.98s OK
#    |     0.00s reassigning feature values ...
#    |     0.72s OK
# True

# %% [markdown]
# ### Configure a TF app
#
# The TF app has configuration settings, a bit of custom code, and documentation.
#
# Most of it will be generated now, but there are ways to keep custom additions intact.

# %%
Tei.task(app=True)
# Out:
# True

# %% [markdown]
# ### Use the new dataset
#
# The final proof that the conversion has worked is to load the data.
# On first-time loading several checks and pre-computations are performed.
# Next time the loading will be much quicker.

# %%
A = use(f"{Tei.org}/{Tei.repo}:clone", backend=Tei.backend, checkout="clone", silent="verbose", hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/HuygensING/translatin/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/HuygensING/translatin/tf/0.0.1</span>
# This is Text-Fabric 12.6.2
# 41 features found and 0 ignored
#    |     0.52s T otype                from ~/github/HuygensING/translatin/tf/0.0.1
#    |     6.33s T oslots               from ~/github/HuygensING/translatin/tf/0.0.1
#   6.85s Dataset without structure sections in otext:no structure functions in the T-API
#    |     0.34s T chunk                from ~/github/HuygensING/translatin/tf/0.0.1
#    |     0.01s T part                 from ~/github/HuygensING/translatin/tf/0.0.1
#    |     0.00s T work                 from ~/github/HuygensING/translatin/tf/0.0.1
#    |     3.25s T after                from ~/github/HuygensING/translatin/tf/0.0.1
#    |     3.99s T str                  from ~/github/HuygensING/translatin/tf/0.0.1
#    |      |     0.13s C __levels__           from otype, oslots, otext
#    |      |     9.31s C __order__            from otype, oslots, __levels__
#    |      |     0.37s C __rank__             from otype, __order__
#    |      |       13s C __levUp__            from otype, oslots, __rank__
#    |      |     3.66s C __levDown__          from otype, __levUp__, __rank__
#    |      |     0.39s C __characters__       from otext
#    |      |     3.60s C __boundary__         from otype, oslots, __rank__
#    |      |     1.91s C __sections__         from otype, oslots, otext, __levUp__, __levDown__, __levels__, work, part, chunk
#     47s All features loaded / computed - for details use TF.isLoaded()
#    |     0.00s T acts                 from ~/github/HuygensING/translatin/tf/0.0.1
#    |     0.00s T author               from ~/github/HuygensING/translatin/tf/0.0.1
#    |     0.00s T chorus               from ~/github/HuygensING/translatin/tf/0.0.1
#    |     0.00s T diction              from ~/github/HuygensING/translatin/tf/0.0.1
#    |     0.00s T editor               from ~/github/HuygensING/translatin/tf/0.0.1
#    |     0.01s T empty                from ~/github/HuygensING/translatin/tf/0.0.1
#    |     0.03s T extraspace           from ~/github/HuygensING/translatin/tf/0.0.1
#    |     0.00s T facs                 from ~/github/HuygensING/translatin/tf/0.0.1
#    |     0.00s T firstEdition         from ~/github/HuygensING/translatin/tf/0.0.1
#    |     0.00s T genre                from ~/github/HuygensING/translatin/tf/0.0.1
#    |     0.01s T id                   from ~/github/HuygensING/translatin/tf/0.0.1
#    |     0.03s T is_meta              from ~/github/HuygensING/translatin/tf/0.0.1
#    |     0.06s T is_note              from ~/github/HuygensING/translatin/tf/0.0.1
#    |     0.01s T link_target          from ~/github/HuygensING/translatin/tf/0.0.1
#    |     0.00s T medium               from ~/github/HuygensING/translatin/tf/0.0.1
#    |     0.01s T n                    from ~/github/HuygensING/translatin/tf/0.0.1
#    |     0.00s T pubPlace             from ~/github/HuygensING/translatin/tf/0.0.1
#    |     0.00s T pubYear              from ~/github/HuygensING/translatin/tf/0.0.1
#    |     0.00s T publisher            from ~/github/HuygensING/translatin/tf/0.0.1
#    |     0.03s T rend                 from ~/github/HuygensING/translatin/tf/0.0.1
#    |     0.01s T rend_bold            from ~/github/HuygensING/translatin/tf/0.0.1
#    |     0.01s T rend_footnote        from ~/github/HuygensING/translatin/tf/0.0.1
#    |     0.04s T rend_italic          from ~/github/HuygensING/translatin/tf/0.0.1
#    |     0.00s T rend_superscript     from ~/github/HuygensING/translatin/tf/0.0.1
#    |     0.00s T rend_underline       from ~/github/HuygensING/translatin/tf/0.0.1
#    |     0.00s T sourceLink           from ~/github/HuygensING/translatin/tf/0.0.1
#    |     0.01s T target               from ~/github/HuygensING/translatin/tf/0.0.1
#    |     0.00s T titleExpanded        from ~/github/HuygensING/translatin/tf/0.0.1
#    |     0.00s T titleFull            from ~/github/HuygensING/translatin/tf/0.0.1
#    |     0.00s T titleShort           from ~/github/HuygensING/translatin/tf/0.0.1
#    |     0.00s T transcribers         from ~/github/HuygensING/translatin/tf/0.0.1
#    |     0.01s T type                 from ~/github/HuygensING/translatin/tf/0.0.1
#    |     0.00s T unit                 from ~/github/HuygensING/translatin/tf/0.0.1
#   0.30s All additional features loaded - for details use TF.isLoaded()
#             <b>TF:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric api">TF API 12.6.2</a>, <a target="_blank" href="https://github.com/HuygensING/translatin/blob/main/app" title="HuygensING/translatin app">HuygensING/translatin/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://github.com/HuygensING/translatin/blob/main/docs/about.md" title="provenance of HuygensING - translatin/tf">HuygensING - translatin 0.0.1</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://github.com/HuygensING/translatin/blob/main/docs/transcription.md" title="HuygensING - translatin feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots / node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>work</th>
#     <td>118</td>
#     <td>14053.36</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>body</th>
#     <td>118</td>
#     <td>13910.93</td>
#     <td>99</td>
# </tr>
#
# <tr>
#     <th>text</th>
#     <td>118</td>
#     <td>13910.93</td>
#     <td>99</td>
# </tr>
#
# <tr>
#     <th>div</th>
#     <td>2864</td>
#     <td>573.15</td>
#     <td>99</td>
# </tr>
#
# <tr>
#     <th>part</th>
#     <td>2982</td>
#     <td>556.10</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>page</th>
#     <td>1320</td>
#     <td>181.89</td>
#     <td>14</td>
# </tr>
#
# <tr>
#     <th>teiHeader</th>
#     <td>118</td>
#     <td>142.42</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>bibl</th>
#     <td>118</td>
#     <td>75.37</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>sourceDesc</th>
#     <td>118</td>
#     <td>75.37</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>titleStmt</th>
#     <td>118</td>
#     <td>55.74</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>respStmt</th>
#     <td>118</td>
#     <td>22.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>editor</th>
#     <td>118</td>
#     <td>18.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>name</th>
#     <td>236</td>
#     <td>12.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>list</th>
#     <td>246</td>
#     <td>9.02</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>item</th>
#     <td>254</td>
#     <td>8.74</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>chunk</th>
#     <td>193149</td>
#     <td>8.59</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>fileDesc</th>
#     <td>118</td>
#     <td>137.42</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>p</th>
#     <td>190054</td>
#     <td>8.57</td>
#     <td>98</td>
# </tr>
#
# <tr>
#     <th>note</th>
#     <td>3109</td>
#     <td>9.21</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>emph</th>
#     <td>118</td>
#     <td>8.46</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>publicationStmt</th>
#     <td>118</td>
#     <td>6.31</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>quote</th>
#     <td>70</td>
#     <td>5.70</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>keywords</th>
#     <td>118</td>
#     <td>5.01</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>profileDesc</th>
#     <td>118</td>
#     <td>5.01</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>textClass</th>
#     <td>118</td>
#     <td>5.01</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>title</th>
#     <td>354</td>
#     <td>4.36</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>head</th>
#     <td>2826</td>
#     <td>4.28</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>author</th>
#     <td>118</td>
#     <td>3.64</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>publisher</th>
#     <td>118</td>
#     <td>2.20</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>hi</th>
#     <td>13706</td>
#     <td>2.04</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>date</th>
#     <td>236</td>
#     <td>2.01</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>ref</th>
#     <td>368</td>
#     <td>1.42</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>pubPlace</th>
#     <td>118</td>
#     <td>1.08</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>term</th>
#     <td>590</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>lb</th>
#     <td>1180</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>milestone</th>
#     <td>169</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>pb</th>
#     <td>1320</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>ptr</th>
#     <td>3109</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>resp</th>
#     <td>118</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th><i>t</i></th>
#     <td>1658296</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b>HuygensING - translatin/tf</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/HuygensING/translatin/blob/main/docs/transcription.md" title="~/github/HuygensING/translatin/tf/0.0.1/acts.tf">acts</a>
# </div>
# <div class="fmono">int</div>
#
# <details>
#     <summary>Number of acts</summary>
#     <div class="fmeta">
#
# <div class="fmetarow">
#     <div class="fmetakey">contributors1:</div>
#     <div>Hennie Brugman, Hayco de Jong, Bram Buitendijk, Sebastiaan van Daalen, Dirk Roorda</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">conversionCode:</div>
#     <div>tt</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">conversionMethod:</div>
#     <div>derived</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">converter:</div>
#     <div>Dirk Roorda (Text-Fabric)</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">dateWritten:</div>
#     <div>2024-12-27T09:18:48+00:00Z</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">descriptionTf:</div>
#     <div>Edition</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">editor:</div>
#     <div>Jan Bloemendal</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">institute1:</div>
#     <div>HuC (Humanities Cluster) Amsterdam</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">institute2:</div>
#     <div>Huygens Instituut Amsterdam</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">language:</div>
#     <div>la</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">schema:</div>
#     <div>TEI + translatin</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">sourceFormat:</div>
#     <div>TEI</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">teiVersion:</div>
#     <div>not specified</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">title:</div>
#     <div>Translatin (drama, 1500-1750))</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">version:</div>
#     <div>0.0.1</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">writtenBy:</div>
#     <div>Text-Fabric</div>
# </div>
#
#     </div>
# </details>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/HuygensING/translatin/blob/main/docs/transcription.md" title="~/github/HuygensING/translatin/tf/0.0.1/after.tf">after</a>
# </div>
# <div class="fmono">str</div>
#
# <details>
#     <summary>the text after a word till the next word</summary>
#     <div class="fmeta">
#
# <div class="fmetarow">
#     <div class="fmetakey">contributors1:</div>
#     <div>Hennie Brugman, Hayco de Jong, Bram Buitendijk, Sebastiaan van Daalen, Dirk Roorda</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">conversionCode:</div>
#     <div>tf</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">conversionMethod:</div>
#     <div>literal-composed</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">converter:</div>
#     <div>Dirk Roorda (Text-Fabric)</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">dateWritten:</div>
#     <div>2024-12-27T09:18:48+00:00Z</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">descriptionTf:</div>
#     <div>Edition</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">editor:</div>
#     <
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/browser/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/browser/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/browser/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/browser/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/browser/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/browser/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/browser/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/browser/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
#
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .txtu.uga,.lex.uga {
#     font-family: sans-serif;
#     /*font-family: Noto Sans Ugaritic, sans-serif;*/
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .nde, a:link.nde {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .etf {
#     font-size: normal;
#     border-radius: 0.2rem;
#     border: 1pt solid white;
#     padding: 0 0.2rem ! important;
#     margin: 0 0.2rem ! important;
# }
# .etfx {
#     font-size: x-large;
# }
# .lex {
#   color: var(--lex-color);;
# }
# #colormapplus, #colormapmin, .ecolormapmin {
#   font-weight: bold;
#   border-radius: 0.1rem;
#   background-color: #eeeeff;
#   padding: 0 1rem;
#   margin: 0 1rem;
# }
# .clr {
#   font-style: italic;
#   font-size: small;
# }
# .clmap,.eclmap {
#   padding: 0;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .c
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <div><b>TF API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF Fs Fall Es Eall Cs Call</a> directly usable</div><hr>

# %% [markdown]
# ## Step 6: Convert TF to WATM
#
# N.B. For docs click the WATM link in the output cell.

# %%
WA = WATM(A, "tei", skipMeta=False, prod=True)
# WA = WATM(A, "tei", skipMeta=False, prod=False)
WA.makeText()
WA.makeAnno()
WA.writeAll()
WA.testAll()
# Out:
# textRepoLevel is section level 'work'
# [WATM exporter documentation](https://annotation.github.io/text-fabric/tf/convert/watm.html)
# 	Writing WATM ...
# Writing production data to ~/github/HuygensING/translatin/watm/0.0.1-004/prod
# Text file    0:    11457 segments to ~/github/HuygensING/translatin/watm/0.0.1-004/prod/text-0.tsv
# Text file    1:    10801 segments to ~/github/HuygensING/translatin/watm/0.0.1-004/prod/text-1.tsv
# Text file    2:    44717 segments to ~/github/HuygensING/translatin/watm/0.0.1-004/prod/text-2.tsv
# Text file    3:     1125 segments to ~/github/HuygensING/translatin/watm/0.0.1-004/prod/text-3.tsv
# Text file    4:    14000 segments to ~/github/HuygensING/translatin/watm/0.0.1-004/prod/text-4.tsv
#
# Text files all:  1658296 segments to 118 files
# Anno file    1:   356385 annotations written to ~/github/HuygensING/translatin/watm/0.0.1-004/prod/anno-1.tsv
# Anno files all:   356385 annotations to 1 file
# Slot mapping written to ~/github/HuygensING/translatin/watm/0.0.1-004/prod/pos2node.tsv
# Node mapping written to ~/github/HuygensING/translatin/watm/0.0.1-004/prod/anno2node.tsv
# 	Testing WATM ...
# Testing the text ...
# 	TF: 1658296
# 	WA: 1658296
# OK - whether the amounts of tokens agree
# 	TF: Philodoxeos Fabula P ... is? Back F I N I S.
# 	WA: Philodoxeos Fabula P ... is? Back F I N I S.
# OK - whether the text is the same
# Testing the elements ...
# 	TF: 224735
# 	WA: 224735
# OK - whether the amounts of elements and nodes agree
# Testing the processing instructions ...
# 	TF:      0
# 	WA:      0
# OK - whether the amounts of processing instructions agree
# Testing the element/pi annotations ...
# 	1883031 element/pi annotations
# 	Element      : 224735 x
# 	Pi           :      0 x
# 	Other        : 131650 x
# 	Good name    : 224735 x
# 	Wrong name   :      0 x
# 	Good target  : 224735 x
# 	Wrong target :      0 x
# 	Unmapped     :      0 x
# OK - whether all element/pi annotations have good bodies
# OK - whether all element/pi annotations have good targets
# Testing the attributes ...
# 	72023 attribute values
# 	Good:     72023 x
# 	Wrong:        0 x
# OK - whether annotations are consistent with features
# 	WA attributes: 72023
# 	TF attributes: 72023
# OK - whether annotations are complete w.r.t. features
# Testing the format attributes ...
# 	27869 format values
# 	formatting attributes:
# 		 20341 x italic
# 		  4272 x bold
# 		  3109 x footnote
# 		   128 x underline
# 		    19 x superscript
# 	Good:     27869 x
# 	Wrong:        0 x
# OK - whether format annotations are consistent with features
# 	WA format attributes: 27869
# 	TF format attributes: 27869
# OK - whether format annotations are complete w.r.t. features
# Testing the extra annotations ...
# 	0 extra feature values
# 	0 extra annotations
# OK - whether the extra annotations agree
# Testing the edges ...
# 	Found: 1883031 nodes
# 	Found edge link_target with 3109 starting nodes
# 	Checking edge link_target
# 		same 3109 fromNodes
# 	OK - 3109 toNodes checked
# OK - whether all edges agree
# Overall outcome ...
# OK - whether all tests passed

# %% [markdown]
# ## Step 8: Deploy to k8s and TeamText VM

# %% [markdown]
# NB: you need to have access to the k8s cluster and to the team text VM.
#
# That means:
#
# * The LDAP of the relevant k8s clusters know you
# * You have an ssh key-based login on the Team Text VPN
# * You work inside the firewall

# %%
# !./provision.sh watm
# Out:
# k-suite enabled
# Context "k8s-10-26-2-0" modified.
#
# Quick access to iiif-suriano : type khelp for an overview of commands.
#
# WATM export version: 1.0.1e-029
# anno-1.tsv                                    100%   17MB   5.9MB/s   00:02
# anno-3.tsv                                    100%   10MB   6.4MB/s   00:01
# anno-2.tsv                                    100%   15MB   6.6MB/s   00:02
# anno2node.tsv                                 100% 5658KB   5.9MB/s   00:00
# text-6.tsv                                    100% 1228KB   4.3MB/s   00:00
# text-7.tsv                                    100% 1196KB   4.1MB/s   00:00
# text-5.tsv                                    100% 1018KB   6.0MB/s   00:00
# text-4.tsv                                    100%  914KB   5.8MB/s   00:00
# text-0.tsv                                    100%  267KB   4.3MB/s   00:00
# text-1.tsv                                    100%  705KB   6.2MB/s   00:00
# text-3.tsv                                    100%  655KB   6.0MB/s   00:00
# text-2.tsv                                    100%  879KB   6.3MB/s   00:00
# text-9.tsv                                    100% 1337KB   6.0MB/s   00:00
# text-8.tsv                                    100% 1389KB   5.3MB/s   00:00
# entitymeta.json                               100%  339KB   5.3MB/s   00:00
# pos2node.tsv                                  100%   26MB   6.2MB/s   00:04
# text-10.tsv                                   100%  776KB   5.2MB/s   00:00
# logicalpairs.tsv                              100%  177KB   4.7MB/s   00:00

# %%
# !./provision.sh files
# Out:
# k-suite enabled
# Context "k8s-10-26-2-0" modified.
#
# Quick access to iiif-suriano : type khelp for an overview of commands.
#
# copying to pod: prod/covers.html
# copying to pod: prod/logo
# copying to pod: prod/manifests
# copying to pod: both/metadata
