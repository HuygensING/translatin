# %% [markdown]
# # Convert from DOCX to TEI to TF to WATM
#
# We convert DOCX to TEI to TF and then to WATM.
#
# This notebook provides three levels of refinement in the execution. They all have the same outcome,
# but they differ in the level of detail they provide on the conversion.
#
# These are the levels:
#
# * **Debugging**: all the commands directly in Python, the intermediate data remains in memory and can  be inspected.
# * **Step by step**: one command for each main step of the conversion;
# * **Express**: one single command on the command line for the complete conversion;

# %% [markdown]
# # Production or development
#
# Mosts steps are unaffected by the production/development setting.
#
# In the first steps of the pipeline (*ingest* and *scan processing*) we prepare both the dev and the prod data.
#
# The intermediate steps (*from DOCX to TEI*, *from TEI to TF*, *mark named entities*) are identical for prod and dev.
#
# Only for the latter steps (*convert TF to WATM*, generate IIIF manifests*, *deploy to k8s*) there is a distinction between prod and dev.
#
# For these steps we have commented out the line that does the dev version.

# %% [markdown]
# # Requirements
#
# * zsh as command line shell (as in macOS);
# * access to suitable k8s clusters, streamlined by the
#   [k-suite](https://code.huc.knaw.nl/tt/smart-k8s/-/blob/main/docs/k-suite.md);
# * [Pandoc](https://pandoc.org)
# * [Python](https://www.python.org) (3.12 or higher) with additional pip-installable modules:
#   * text-fabric
#   * openpyxl

# %% [markdown]
# # Declare the version
#
# Always set the version before running any cell in this notebook!

# %%
VERSION = "0.0.3"

# %% [markdown]
# # In debugging mode.
#
# Now we dig a bit deeper, en do all the steps while keeping the program in memory.
# Now it becomes doable to inspect all intermediate results.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tf.app import use
from tf.convert.tei import TEI
from tf.convert.watm import WATM
from tf.advanced.helpers import dm

from processdocs import TeiFromDocx
from processhelpers import SOURCEBASE, REPORT_TEIDIR

# %% [markdown]
# ## Step 1: From DOCX to TEI

# %% [markdown]
# You might need to do
#
# ```
# pip install docx2python
# ```

# %%
TFD = TeiFromDocx(silent=False)
# Out:
# GET docx files and their metadata from XLS ...
#
# Collecting excel metadata ...
# Metadata collected.
# 0 warnings
# Continuing with 118 good files among 118 in total
# 0 informational messages
# 0 warnings

# %%
# TFD.task("convert", forceClean=True, skipTeix=True, skipTei=True, workName="Zovitius-Ruth")

# %%
# TFD.task("convert", forceClean=True, skipTeix=True, skipTei=True)

# %%
TFD.task("convert", forceClean=True)
# Out:
# DOCX => Markdown per drama ...
# 	   drama                          |   lines | lnums | pages | folios| sect | conversion steps
# 	OK Alberti-Philodoxus             |     891 |     0 |    38 |     0 |   23 | clean special   teisimple tei
# 	OK Aler-Innocentia                |    2755 |     0 |    40 |     0 |   36 | clean special   teisimple tei
# 	OK Balde-Iephtias                 |    9861 |     0 |     0 |     0 |   72 | clean generic   teisimple tei
# 	OK Barlandus-Dialogus             |      95 |     0 |     0 |     0 |    0 | clean generic   teisimple tei
# 	OK Beza-Abrahamus                 |    3137 |     0 |    46 |     0 |    9 | clean special   teisimple tei
# 	OK Brechtus-Euripus               |    6155 |   470 |   112 |    94 |   13 | clean special   teisimple tei
# 	OK Caussin-Felicitas              |    4235 |     0 |     0 |     0 |   23 | clean generic   teisimple tei
# 	OK Caussin-Hermenigildus          |    1145 |     0 |   101 |     0 |    7 | clean special   teisimple tei
# 	OK Caussin-Nabuchodonosor         |    3351 |     0 |     0 |     0 |   15 | clean generic   teisimple tei
# 	OK Caussin-Solyma                 |    3829 |     0 |     0 |     0 |   17 | clean generic   teisimple tei
# 	OK Caussin-Theodoricus            |    3359 |     0 |     0 |     0 |   12 | clean generic   teisimple tei
# 	OK Cellotius-Adrianus             |    5871 |     0 |   103 |     0 |   40 | clean special   teisimple tei
# 	OK Cellotius-Chosroes             |    4151 |     0 |    81 |     0 |   39 | clean special   teisimple tei
# 	OK Cellotius-Reviviscentes        |    4681 |     0 |   112 |     0 |   52 | clean special   teisimple tei
# 	OK Cellotius-Sapor                |    6857 |     0 |   137 |     0 |   62 | clean special   teisimple tei
# 	OK Celtis-Ludus                   |     569 |     0 |     0 |     0 |    5 | clean generic   teisimple tei
# 	OK Claus-Vulpanser                |    1451 |   127 |     0 |     0 |   37 | clean generic   teisimple tei
# 	OK Crocus-Ioseph                  |    2125 |   165 |     0 |     0 |   20 | clean generic   teisimple tei
# 	OK Cunaeus-Dido                   |    1813 |   180 |     0 |     0 |    5 | clean generic   teisimple tei
# 	OK Dalanthus-Dido                 |    5379 |   490 |    82 |    19 |   30 | clean special   teisimple tei
# 	OK Diether-Ioseph                 |    6007 |     0 |     0 |     0 |   38 | clean generic   teisimple tei
# 	OK Enden-Philedonius              |    2403 |   197 |     0 |    40 |   25 | clean special   teisimple tei
# 	OK Ens-Auriacus                   |    2305 |     0 |     0 |     0 |   14 | clean generic   teisimple tei
# 	OK Forsett-Pedantius              |    3133 |     0 |   173 |     0 |   32 | clean special   teisimple tei
# 	OK Foxe-Christus                  |    5661 |     0 |   120 |     0 |   42 | clean special   teisimple tei
# 	OK Gnapheus-Acolastus             |    4845 |     0 |     0 |     0 |   30 | clean generic   teisimple tei
# 	OK Gnapheus-Morosophus            |    3217 |     0 |     0 |     0 |   26 | clean generic   teisimple tei
# 	OK Goethals-Soter                 |    3591 |   301 |    63 |    19 |   38 | clean special   teisimple tei
# 	OK Gretser-Timon                  |     393 |    15 |     0 |     0 |    3 | clean generic   teisimple tei
# 	OK Gretser-Underwaldius           |     589 |    16 |     0 |     0 |    2 | clean generic   teisimple tei
# 	OK Grimald-Christus               |    3395 |   317 |     0 |     0 |   29 | clean generic   teisimple tei
# 	OK Grotius-Adamus                 |    4233 |   407 |     0 |     0 |    9 | clean generic   teisimple tei
# 	OK Grotius-Christus               |    3019 |   285 |     0 |     0 |   16 | clean generic   teisimple tei
# 	OK Grotius-Phoenissae             |    4187 |   359 |   127 |    44 |   24 | clean special   teisimple tei
# 	OK Gwalther-Nabal                 |    4443 |     0 |     0 |     0 |   58 | clean generic   teisimple tei
# 	OK Heinsius-Auriacus              |    4445 |     0 |     0 |     0 |   16 | clean generic   teisimple tei
# 	OK Heinsius-Herodes               |    4187 |    17 |    14 |   110 |   10 | clean special   teisimple tei
# 	OK Holonius-Catharina             |    3683 |   323 |    78 |    18 |   51 | clean special   teisimple tei
# 	OK Holonius-Laurentias            |    3245 |   277 |    69 |    17 |   45 | clean special   teisimple tei
# 	OK Honerdus-Thamara               |    3205 |   272 |    56 |    13 |   17 | clean special   teisimple tei
# 	OK Houcharius-Grisellis           |    9281 |   503 |    76 |    37 |    6 | clean special   teisimple tei
# 	OK Houthem-Gedeon                 |    2697 |   192 |     0 |    18 |   27 | clean special   teisimple tei
# 	OK Ischyrius-Homulus              |    4292 |   313 |     0 |    34 |   29 | clean special   teisimple tei
# 	OK Kerckmeister-Codrus            |    1325 |     2 |     0 |     0 |    2 | clean generic   teisimple tei
# 	OK Knuyt-Scornetta                |    1025 |    94 |     0 |    15 |    0 | clean special   teisimple tei
# 	OK Laurimanus-Exodus              |    7785 |   632 |    53 |     0 |   68 | clean special   teisimple tei
# 	OK Laurimanus-Miles               |    6937 |   558 |    59 |     0 |   49 | clean special   teisimple tei
# 	OK Locher-Iudicium                |    1411 |   109 |    21 |     7 |    4 | clean special   teisimple tei
# 	OK Lummenaeus-Abimelech           |    1529 |   129 |    29 |    11 |   10 | clean special   teisimple tei
# 	OK Lummenaeus-Amnon               |    2461 |   226 |    33 |     8 |   11 | clean special   teisimple tei
# 	OK Lummenaeus-Bustum              |    1753 |   159 |    31 |    12 |   10 | clean special   teisimple tei
# 	OK Lummenaeus-Carcer              |    2821 |   234 |    39 |    17 |   13 | clean special   teisimple tei
# 	OK Lummenaeus-Iephte              |    1483 |   117 |    27 |     9 |    8 | clean special   teisimple tei
# 	OK Lummenaeus-Sampson             |    1517 |   129 |    29 |    11 |    9 | clean special   teisimple tei
# 	OK Lummenaeus-Saul                |    1931 |   164 |    36 |    13 |   10 | clean special   teisimple tei
# 	OK Macropedius-Adamus             |    5887 |   533 |     0 |     0 |   65 | clean generic   teisimple tei
# 	OK Macropedius-Aluta              |    1313 |   113 |     0 |     0 |   25 | clean generic   teisimple tei
# 	OK Macropedius-Andrisca           |    2775 |   243 |     0 |    44 |   36 | clean special   teisimple tei
# 	OK Macropedius-Asotus             |    4087 |   370 |     0 |     0 |   43 | clean generic   teisimple tei
# 	OK Macropedius-Bassarus           |    2293 |   203 |     0 |     0 |   33 | clean generic   teisimple tei
# 	OK Macropedius-Hecastus           |    4471 |   406 |     0 |     0 |   44 | clean generic   teisimple tei
# 	OK Macropedius-Hypomone           |    2731 |   249 |     0 |     0 |   27 | clean generic   teisimple tei
# 	OK Macropedius-Iesus              |    2597 |   235 |     0 |     0 |   47 | clean generic   teisimple tei
# 	OK Macropedius-Iosephus           |    4449 |   410 |     0 |     0 |   48 | clean generic   teisimple tei
# 	OK Macropedius-Lazarus            |    3175 |   281 |     0 |     0 |   39 | clean generic   teisimple tei
# 	OK Macropedius-Petriscus          |    3237 |   292 |     0 |     0 |   43 | clean generic   teisimple tei
# 	OK Macropedius-Rebelles           |    2539 |   223 |     0 |     0 |   44 | clean generic   teisimple tei
# 	OK Malapertius-Sedecias           |    3425 |   333 |     0 |     0 |   12 | clean generic   teisimple tei
# 	OK Muretus-Caesar                 |    1279 |     0 |     0 |     0 |   13 | clean generic   teisimple tei
# 	OK Mussato-Ecerinis               |    1331 |   126 |     0 |     0 |   23 | clean generic   teisimple tei
# 	OK Narssius-Gustavus              |    3543 |   286 |    48 |    65 |   15 | clean special   teisimple tei
# 	OK Papaeus-Samarites              |    2125 |   184 |     0 |     0 |   27 | clean generic   teisimple tei
# 	OK Philicinus-Esther              |    4209 |     1 |     0 |     0 |   27 | clean generic   teisimple tei
# 	OK Philicinus-Magdalena           |    4649 |   380 |    67 |     0 |   29 | clean special   teisimple tei
# 	OK Placentius-Clericus            |     443 |    44 |     0 |     4 |    0 | clean special   teisimple tei
# 	OK Placentius-Plausus             |     459 |    36 |     8 |     0 |    1 | clean special   teisimple tei
# 	OK Placentius-Susanna             |    1089 |     0 |     0 |    12 |    4 | clean special   teisimple tei
# 	OK Reuchlin-Henno                 |    1011 |    85 |     0 |     0 |    7 | clean generic   teisimple tei
# 	OK Reuchlin-Sergius               |    1129 |    99 |     0 |     0 |    7 | clean generic   teisimple tei
# 	OK Rosefeldus-Moschus             |    5053 |     0 |     0 |    35 |   32 | clean special   teisimple tei
# 	OK Roulerius-Stuarta              |    3675 |   314 |     0 |     0 |   15 | clean generic   teisimple tei
# 	OK Ruggle-Ignoramus               |    7953 |   743 |     0 |     0 |   60 | clean generic   teisimple tei
# 	OK Salius-Nassovius               |    1781 |   150 |     0 |     0 |   14 | clean generic   teisimple tei
# 	OK Schonaeus-Ananias              |    2965 |   240 |    45 |    15 |   25 | clean special   teisimple tei
# 	OK Schonaeus-Baptistes            |    2657 |   218 |    41 |    14 |   29 | clean special   teisimple tei
# 	OK Schonaeus-Cunae                |    2197 |   175 |    34 |    10 |   19 | clean special   teisimple tei
# 	OK Schonaeus-Daniel               |    2769 |   226 |    42 |    15 |   25 | clean special   teisimple tei
# 	OK Schonaeus-Dyscoli              |    2097 |   169 |    35 |    12 |   23 | clean special   teisimple tei
# 	OK Schonaeus-Fabula               |    2145 |     1 |     0 |    30 |   23 | clean special   teisimple tei
# 	OK Schonaeus-Iosephus             |    4107 |   338 |    61 |    17 |   34 | clean special   teisimple tei
# 	OK Schonaeus-Iuditha              |    4059 |   221 |    59 |    15 |   30 | clean special   teisimple tei
# 	OK Schonaeus-Naaman               |    3995 |   318 |    59 |     0 |   30 | clean special   teisimple tei
# 	OK Schonaeus-Nehemias             |    3317 |   279 |    53 |    17 |   30 | clean special   teisimple tei
# 	OK Schonaeus-Pentecoste           |    2771 |   223 |    40 |    11 |   23 | clean special   teisimple tei
# 	OK Schonaeus-Pseudostratiotae     |    2229 |   179 |    37 |    11 |   23 | clean special   teisimple tei
# 	OK Schonaeus-Saulus               |    3963 |   326 |    57 |    18 |   29 | clean special   teisimple tei
# 	OK Schonaeus-Susanna              |    2963 |   248 |    45 |    13 |   26 | clean special   teisimple tei
# 	OK Schonaeus-Tobaeus              |    4183 |   350 |    68 |     0 |   39 | clean special   teisimple tei
# 	OK Schonaeus-Triumphus            |    2613 |   214 |    37 |     9 |   20 | clean special   teisimple tei
# 	OK Schonaeus-Typhlus              |    2631 |   208 |    38 |    11 |   24 | clean special   teisimple tei
# 	OK Schonaeus-Vitulus              |    2173 |   179 |    39 |    13 |   24 | clean special   teisimple tei
# 	OK Schopper-Ectrachelistes        |    5217 |     0 |   100 |     0 |   32 | clean special   teisimple tei
# 	OK Simonides-Castus               |    3917 |   351 |    77 |    28 |   15 | clean special   teisimple tei
# 	OK Stymmelius-Isaac               |    3513 |    53 |     0 |     0 |   35 | clean special   teisimple tei
# 	OK Stymmelius-Studentes           |    3363 |     0 |     0 |     0 |   35 | clean generic   teisimple tei
# 	OK Susius-Pendularia              |    1841 |   150 |    35 |    10 |   20 | clean special   teisimple tei
# 	OK Telesio-Imber                  |    2715 |   219 |    50 |    15 |   21 | clean special   teisimple tei
# 	OK Vernulaeus-Conradinus          |    4569 |   404 |    74 |    25 |   36 | clean special   teisimple tei
# 	OK Vernulaeus-Crispus             |    3217 |   284 |    54 |    17 |   35 | clean special   teisimple tei
# 	OK Vernulaeus-Gorcomienses        |    5377 |   449 |   123 |    37 |   35 | clean special   teisimple tei
# 	OK Vernulaeus-Henricus            |    5127 |     0 |     0 |     0 |   52 | clean generic   teisimple tei
# 	OK Vernulaeus-Theodoricus         |    4359 |   378 |    72 |    22 |   54 | clean special   teisimple tei
# 	OK Vladeraccus-Tobias             |    3775 |   299 |     0 |     0 |   54 | clean generic   teisimple tei
# 	OK Weitenauer-Annibal             |    3659 |   329 |     0 |     0 |   46 | clean generic   teisimple tei
# 	OK Wimpheling-Stylpho             |     217 |     0 |     0 |     0 |    8 | clean special   teisimple tei
# 	OK Zevecotius-Rosimunda           |    2667 |   215 |    56 |     9 |   10 | clean special   teisimple tei
# 	OK Zovitius-Didascalus            |    1623 |   143 |     0 |     0 |   19 | clean generic   teisimple tei
# 	OK Zovitius-Ruth                  |    3709 |   326 |     0 |     0 |   27 | clean generic   teisimple tei
# 	OK All dramas (118)               |  385551 | 21830 |  3539 |  1120 | 3088 | done
# Dramas without specifics defined: 0
# See for pages: ~/github/HuygensING/translatin/report/trans/lines.yml
# See for pages: ~/github/HuygensING/translatin/report/trans/pages.yml
# See for sections: ~/github/HuygensING/translatin/report/trans/sections.yml
# 0 informational messages
# 0 warnings

# %% [markdown]
# ## Step 4: From TEI to TF
#
# ### Check the validity of the TEI.

# %%
Tei = TEI(verbose=-1, sourceBase=SOURCEBASE, reportDir=REPORT_TEIDIR, tei="", tf=VERSION)

# %%
# validate = 1
validate = True
Tei.task(check=True, verbose=1, validate=validate)
# Out:
# TEI to TF checking: ~/github/HuygensING/translatin/tei => ~/github/HuygensING/translatin/report/tei
# Processing instructions are ignored
# XML validation will be performed
# Analysing ~/github/annotation/text-fabric/tf/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/annotation/text-fabric/tf/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/HuygensING/translatin/schema/translatin.xsd
# Warning: tei:tei_model.frontPart.kind is not defined.
# 	round   1:  49 changes
# Warning: tei:tei_model.frontPart.kind is not defined.
#  91 identical override(s)
#   0 changing override(s)
# Section model III
# 118 translatin file(s) ...
# 	Validating ...
# 	Making inventory ...
#
# 584 tag(s) type info written to ~/github/HuygensING/translatin/report/tei/types.txt
# Validation OK
# 35 tags of which 0 with multiple namespaces written to ~/github/HuygensING/translatin/report/tei/namespaces.txt
# 972 info line(s) written to ~/github/HuygensING/translatin/report/tei/elements.txt
# Refs written to ~/github/HuygensING/translatin/report/tei/refs.txt
# 	resolvable: 3109 in 3109
# 	dangling:      1 in    1
# 	ALL:        3110 in 3110
# Ids written to ~/github/HuygensING/translatin/report/tei/ids.txt
# 	referenced: 3109 by 3109
# 	non-unique:    0
# 	unused:     3126
# 	ALL:        6235 in 6235
# lb-parent info written to ~/github/HuygensING/translatin/report/tei/lb-parents.txt
# True

# %% [markdown]
# ### Convert the data

# %%
Tei.good = True
Tei.task(convert=True, verbose=0)
# Out:
# Section model III
# Processing instructions are ignored
# Analysing ~/github/annotation/text-fabric/tf/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/annotation/text-fabric/tf/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/HuygensING/translatin/schema/translatin.xsd
# Warning: tei:tei_model.frontPart.kind is not defined.
# 	round   1:  49 changes
# Warning: tei:tei_model.frontPart.kind is not defined.
#  91 identical override(s)
#   0 changing override(s)
#   0.00s Importing data from walking through the source ...
#    |     0.00s Preparing metadata...
#    |     0.00s OK
#    |     0.00s Following director...
# 		   1 translatin                             Alberti-Philodoxus.xml
# 		   2 translatin                             Aler-Innocentia.xml
# 		   3 translatin                             Balde-Iephtias.xml
# 		   4 translatin                             Barlandus-Dialogus.xml
# 		   5 translatin                             Beza-Abrahamus.xml
#
# Resolving links into edges ...
# 	3109 in 3109 reference(s) resolved
# 	1 in 1 reference(s): could not be resolved
#    |     7.87s "delete" actions: 0
#    |     7.87s "edge" actions: 3109
#    |     7.87s "feature" actions: 1971614
#    |     7.87s "node" actions: 239717
#    |     7.87s "resume" actions: 0
#    |     7.87s "slot" actions: 1651751
#    |     7.87s "terminate" actions: 239717
#    |    1891468 nodes of all types
#    |     7.96s OK
#    |     0.00s checking for nodes and edges ...
#    |     0.00s OK
#    |     0.00s checking (section) features ...
#    |     0.02s OK
#    |     0.00s reordering nodes ...
#    |     0.84s Max node = 1891468
#    |     0.84s OK
#    |     0.00s reassigning feature values ...
#    |     0.65s OK
# True

# %% [markdown]
# ### Configure a TF app
#
# The TF app has configuration settings, a bit of custom code, and documentation.
#
# Most of it will be generated now, but there are ways to keep custom additions intact.

# %%
Tei.task(app=True)
# Out:
# True

# %% [markdown]
# ### Use the new dataset
#
# The final proof that the conversion has worked is to load the data.
# On first-time loading several checks and pre-computations are performed.
# Next time the loading will be much quicker.

# %%
A = use(f"{Tei.org}/{Tei.repo}:clone", backend=Tei.backend, checkout="clone", silent="verbose", hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/HuygensING/translatin/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/HuygensING/translatin/tf/0.0.3</span>
# This is Text-Fabric 12.6.4
# 43 features found and 0 ignored
#    |     0.37s T otype                from ~/github/HuygensING/translatin/tf/0.0.3
#    |     4.62s T oslots               from ~/github/HuygensING/translatin/tf/0.0.3
#   4.99s Dataset without structure sections in otext:no structure functions in the T-API
#    |     0.03s T chunk                from ~/github/HuygensING/translatin/tf/0.0.3
#    |     3.31s T after                from ~/github/HuygensING/translatin/tf/0.0.3
#    |     4.13s T str                  from ~/github/HuygensING/translatin/tf/0.0.3
#    |     0.00s T part                 from ~/github/HuygensING/translatin/tf/0.0.3
#    |     0.00s T drama                from ~/github/HuygensING/translatin/tf/0.0.3
#    |      |     0.08s C __levels__           from otype, oslots, otext
#    |      |       10s C __order__            from otype, oslots, __levels__
#    |      |     0.33s C __rank__             from otype, __order__
#    |      |       11s C __levUp__            from otype, oslots, __rank__
#    |      |     1.96s C __levDown__          from otype, __levUp__, __rank__
#    |      |     0.40s C __characters__       from otext
#    |      |     3.17s C __boundary__         from otype, oslots, __rank__
#    |      |     0.16s C __sections__         from otype, oslots, otext, __levUp__, __levDown__, __levels__, drama, part, chunk
#     40s All features loaded / computed - for details use TF.isLoaded()
#    |     0.00s T acts                 from ~/github/HuygensING/translatin/tf/0.0.3
#    |     0.00s T author               from ~/github/HuygensING/translatin/tf/0.0.3
#    |     0.00s T chorus               from ~/github/HuygensING/translatin/tf/0.0.3
#    |     0.00s T diction              from ~/github/HuygensING/translatin/tf/0.0.3
#    |     0.00s T editor               from ~/github/HuygensING/translatin/tf/0.0.3
#    |     0.02s T empty                from ~/github/HuygensING/translatin/tf/0.0.3
#    |     0.03s T extraspace           from ~/github/HuygensING/translatin/tf/0.0.3
#    |     0.01s T facs                 from ~/github/HuygensING/translatin/tf/0.0.3
#    |     0.00s T firstEdition         from ~/github/HuygensING/translatin/tf/0.0.3
#    |     0.00s T genre                from ~/github/HuygensING/translatin/tf/0.0.3
#    |     0.02s T id                   from ~/github/HuygensING/translatin/tf/0.0.3
#    |     0.03s T is_meta              from ~/github/HuygensING/translatin/tf/0.0.3
#    |     0.06s T is_note              from ~/github/HuygensING/translatin/tf/0.0.3
#    |     0.01s T link_target          from ~/github/HuygensING/translatin/tf/0.0.3
#    |     0.00s T medium               from ~/github/HuygensING/translatin/tf/0.0.3
#    |     0.01s T n                    from ~/github/HuygensING/translatin/tf/0.0.3
#    |     0.00s T pubPlace             from ~/github/HuygensING/translatin/tf/0.0.3
#    |     0.00s T pubYear              from ~/github/HuygensING/translatin/tf/0.0.3
#    |     0.00s T publisher            from ~/github/HuygensING/translatin/tf/0.0.3
#    |     0.03s T rend                 from ~/github/HuygensING/translatin/tf/0.0.3
#    |     0.01s T rend_bold            from ~/github/HuygensING/translatin/tf/0.0.3
#    |     0.01s T rend_footnote        from ~/github/HuygensING/translatin/tf/0.0.3
#    |     0.04s T rend_italic          from ~/github/HuygensING/translatin/tf/0.0.3
#    |     0.00s T rend_superscript     from ~/github/HuygensING/translatin/tf/0.0.3
#    |     0.00s T rend_underline       from ~/github/HuygensING/translatin/tf/0.0.3
#    |     0.00s T source               from ~/github/HuygensING/translatin/tf/0.0.3
#    |     0.00s T sourceDescription    from ~/github/HuygensING/translatin/tf/0.0.3
#    |     0.00s T sourceLink           from ~/github/HuygensING/translatin/tf/0.0.3
#    |     0.01s T target               from ~/github/HuygensING/translatin/tf/0.0.3
#    |     0.00s T titleExpanded        from ~/github/HuygensING/translatin/tf/0.0.3
#    |     0.00s T titleFull            from ~/github/HuygensING/translatin/tf/0.0.3
#    |     0.00s T titleShort           from ~/github/HuygensING/translatin/tf/0.0.3
#    |     0.00s T transcribers         from ~/github/HuygensING/translatin/tf/0.0.3
#    |     0.01s T type                 from ~/github/HuygensING/translatin/tf/0.0.3
#    |     0.01s T unit                 from ~/github/HuygensING/translatin/tf/0.0.3
#   0.32s All additional features loaded - for details use TF.isLoaded()
#             <b>TF:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric api">TF API 12.6.4</a>, <a target="_blank" href="https://github.com/HuygensING/translatin/blob/main/app" title="HuygensING/translatin app">HuygensING/translatin/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://github.com/HuygensING/translatin/blob/main/docs/about.md" title="provenance of HuygensING - translatin/tf">HuygensING - translatin 0.0.3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://github.com/HuygensING/translatin/blob/main/docs/transcription.md" title="HuygensING - translatin feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots / node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>drama</th>
#     <td>118</td>
#     <td>13997.89</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>body</th>
#     <td>118</td>
#     <td>13889.82</td>
#     <td>99</td>
# </tr>
#
# <tr>
#     <th>text</th>
#     <td>118</td>
#     <td>13889.82</td>
#     <td>99</td>
# </tr>
#
# <tr>
#     <th>part</th>
#     <td>510</td>
#     <td>3238.73</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>chunk</th>
#     <td>13522</td>
#     <td>122.15</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>div</th>
#     <td>2928</td>
#     <td>1066.98</td>
#     <td><i>189</i></td>
# </tr>
#
# <tr>
#     <th>teiHeader</th>
#     <td>118</td>
#     <td>108.07</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>fileDesc</th>
#     <td>118</td>
#     <td>103.06</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>bibl</th>
#     <td>118</td>
#     <td>75.37</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>sourceDesc</th>
#     <td>118</td>
#     <td>75.37</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>titleStmt</th>
#     <td>118</td>
#     <td>23.38</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>list</th>
#     <td>245</td>
#     <td>9.04</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>item</th>
#     <td>253</td>
#     <td>8.76</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>p</th>
#     <td>189877</td>
#     <td>8.54</td>
#     <td>98</td>
# </tr>
#
# <tr>
#     <th>note</th>
#     <td>3109</td>
#     <td>9.21</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>emph</th>
#     <td>118</td>
#     <td>8.46</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>respStmt</th>
#     <td>118</td>
#     <td>6.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>head</th>
#     <td>2890</td>
#     <td>5.97</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>quote</th>
#     <td>70</td>
#     <td>5.70</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>keywords</th>
#     <td>118</td>
#     <td>5.01</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>profileDesc</th>
#     <td>118</td>
#     <td>5.01</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>textClass</th>
#     <td>118</td>
#     <td>5.01</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>publicationStmt</th>
#     <td>118</td>
#     <td>4.31</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>title</th>
#     <td>354</td>
#     <td>4.25</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>name</th>
#     <td>236</td>
#     <td>4.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>author</th>
#     <td>118</td>
#     <td>3.64</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>publisher</th>
#     <td>118</td>
#     <td>2.20</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>editor</th>
#     <td>118</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>hi</th>
#     <td>13444</td>
#     <td>1.98</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>ref</th>
#     <td>268</td>
#     <td>1.57</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>pubPlace</th>
#     <td>118</td>
#     <td>1.08</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>date</th>
#     <td>236</td>
#     <td>1.01</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>term</th>
#     <td>590</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>lb</th>
#     <td>1180</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>milestone</th>
#     <td>4654</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>ptr</th>
#     <td>3109</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>resp</th>
#     <td>118</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th><i>t</i></th>
#     <td>1651751</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b>HuygensING - translatin/tf</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/HuygensING/translatin/blob/main/docs/transcription.md" title="~/github/HuygensING/translatin/tf/0.0.3/acts.tf">acts</a>
# </div>
# <div class="fmono">int</div>
#
# <details>
#     <summary>Number of acts</summary>
#     <div class="fmeta">
#
# <div class="fmetarow">
#     <div class="fmetakey">contributors1:</div>
#     <div>Hennie Brugman, Hayco de Jong, Bram Buitendijk, Sebastiaan van Daalen, Dirk Roorda</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">conversionCode:</div>
#     <div>tt</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">conversionMethod:</div>
#     <div>derived</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">converter:</div>
#     <div>Dirk Roorda (Text-Fabric)</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">dateWritten:</div>
#     <div>2025-02-25T13:49:05+00:00Z</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">descriptionTf:</div>
#     <div>Edition</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">editor:</div>
#     <div>Jan Bloemendal</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">institute1:</div>
#     <div>HuC (Humanities Cluster) Amsterdam</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">institute2:</div>
#     <div>Huygens Instituut Amsterdam</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">language:</div>
#     <div>la</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">schema:</div>
#     <div>TEI + translatin</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">sourceFormat:</div>
#     <div>TEI</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">teiVersion:</div>
#     <div>not specified</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">title:</div>
#     <div>Translatin (drama, 1500-1750))</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">version:</div>
#     <div>0.0.3</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">writtenBy:</div>
#     <div>Text-Fabric</div>
# </div>
#
#     </div>
# </details>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/HuygensING/translatin/blob/main/docs/transcription.md" title="~/github/HuygensING/translatin/tf/0.0.3/after.tf">after</a>
# </div>
# <div class="fmono">str</div>
#
# <details>
#     <summary>the text after a word till the next word</summary>
#     <div class="fmeta">
#
# <div class="fmetarow">
#     <div class="fmetakey">contributors1:</div>
#     <div>Hennie Brugman, Hayco de Jong, Bram Buitendijk, Sebastiaan van Daalen, Dirk Roorda</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">conversionCode:</div>
#     <div>tf</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">conversionMethod:</div>
#     <div>literal-composed</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">converter:</div>
#     <div>Dirk Roorda (Text-Fabric)</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">dateWritten:</div>
#     <div>2025-02-25T13:49:05+00:00Z</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">descriptionTf:</div>
#     <div>Edition</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">editor:</div>
#     <div>Jan Bloemendal</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">institute1:</div>
#     <div>HuC (Humanities Cluster) Amsterdam</div>
# </di
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/browser/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/browser/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/browser/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/browser/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/browser/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/browser/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/browser/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/browser/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
#
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .txtu.uga,.lex.uga {
#     font-family: sans-serif;
#     /*font-family: Noto Sans Ugaritic, sans-serif;*/
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .nde, a:link.nde {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .etf {
#     font-size: normal;
#     border-radius: 0.2rem;
#     border: 1pt solid white;
#     padding: 0 0.2rem ! important;
#     margin: 0 0.2rem ! important;
# }
# .etfx {
#     font-size: x-large;
# }
# .lex {
#   color: var(--lex-color);;
# }
# #colormapplus, #colormapmin, .ecolormapmin {
#   font-weight: bold;
#   border-radius: 0.1rem;
#   background-color: #eeeeff;
#   padding: 0 1rem;
#   margin: 0 1rem;
# }
# .clr {
#   font-style: italic;
#   font-size: small;
# }
# .clmap,.eclmap {
#   padding: 0;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .c
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <div><b>TF API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF Fs Fall Es Eall Cs Call</a> directly usable</div><hr>

# %% [markdown]
# ## Step 6: Convert TF to WATM
#
# N.B. For docs click the WATM link in the output cell.

# %%
WA = WATM(A, "tei", skipMeta=False, prod=True)
# WA = WATM(A, "tei", skipMeta=False, prod=False)
WA.makeText()
WA.makeAnno()
WA.writeAll()
WA.testAll()
# Out:
# conversion settings read from ~/github/HuygensING/translatin/config/watm.yml
# IIIF settings read from ~/github/HuygensING/translatin/config/iiif.yml
# textRepoLevel is section level 'drama'
# [WATM exporter documentation](https://annotation.github.io/text-fabric/tf/convert/watm.html)
# 	Writing WATM ...
# Writing production data to ~/github/HuygensING/translatin/watm/0.0.3-017/prod
# Text file    0:    11469 segments to ~/github/HuygensING/translatin/watm/0.0.3-017/prod/text-0.tsv
# Text file    1:    10815 segments to ~/github/HuygensING/translatin/watm/0.0.3-017/prod/text-1.tsv
# Text file    2:    44732 segments to ~/github/HuygensING/translatin/watm/0.0.3-017/prod/text-2.tsv
# Text file    3:     1091 segments to ~/github/HuygensING/translatin/watm/0.0.3-017/prod/text-3.tsv
# Text file    4:    13976 segments to ~/github/HuygensING/translatin/watm/0.0.3-017/prod/text-4.tsv
#
# Text files all:  1651751 segments to 118 files
# Anno file    1:   368596 annotations written to ~/github/HuygensING/translatin/watm/0.0.3-017/prod/anno-1.tsv
# Inherited annotations: 7650
# Anno files all:   368596 annotations to 1 file
# Slot mapping written to ~/github/HuygensING/translatin/watm/0.0.3-017/prod/pos2node.tsv
# Node mapping written to ~/github/HuygensING/translatin/watm/0.0.3-017/prod/anno2node.tsv
# 	Testing WATM ...
# Testing the text ...
# 	TF: 1651751
# 	WA: 1651751
# OK - whether the amounts of tokens agree
# 	TF: Philodoxeos Fabula P ... obruis? Back FINIS.
# 	WA: Philodoxeos Fabula P ... obruis? Back FINIS.
# OK - whether the text is the same
# Testing the elements ...
# 	TF: 226195
# 	WA: 226195
# OK - whether the amounts of elements and nodes agree
# Testing the processing instructions ...
# 	TF:      0
# 	WA:      0
# OK - whether the amounts of processing instructions agree
# Testing the element/pi annotations ...
# 	1877946 element/pi annotations
# 	Element      : 226195 x
# 	Pi           :      0 x
# 	Other        : 134517 x
# 	Good name    : 226195 x
# 	Wrong name   :      0 x
# 	Good target  : 226195 x
# 	Wrong target :      0 x
# 	Unmapped     :      0 x
# OK - whether all element/pi annotations have good bodies
# OK - whether all element/pi annotations have good targets
# Testing the attributes ...
# 	76223 attribute values
# 	Good:     76223 x
# 	Wrong:        0 x
# OK - whether annotations are consistent with features
# 	WA attributes: 76223
# 	TF attributes: 76223
# OK - whether annotations are complete w.r.t. features
# Testing the format attributes ...
# 	26536 format values
# 	formatting attributes:
# 		 19793 x italic
# 		  3589 x bold
# 		  3109 x footnote
# 		    28 x underline
# 		    17 x superscript
# 	Good:     26536 x
# 	Wrong:        0 x
# OK - whether format annotations are consistent with features
# 	WA format attributes: 26536
# 	TF format attributes: 26536
# OK - whether format annotations are complete w.r.t. features
# Testing the extra annotations ...
# 	0 extra feature values
# 	0 extra annotations
# OK - whether the extra annotations agree
# Testing the edges ...
# 	Found: 1877946 nodes
# 	Found edge link_target with 3109 starting nodes
# 	Checking edge link_target
# 		same 3109 fromNodes
# 	OK - 3109 toNodes checked
# OK - whether all edges agree
# Overall outcome ...
# OK - whether all tests passed

# %% [markdown]
# ## Step 8: Deploy to k8s and TeamText VM

# %% [markdown]
# NB: you need to have access to the k8s cluster and to the team text VM.
#
# That means:
#
# * The LDAP of the relevant k8s clusters know you
# * You have an ssh key-based login on the Team Text VPN
# * You work inside the firewall

# %%
# !./provision.sh watm prod
# Out:
# k-suite enabled
# Context "k8s-10-26-2-0" modified.
#
# Quick access to iiif-translatin : type khelp for an overview of commands.
#
# WATM export version: 0.0.3-017
# text-32.tsv                                   100%   77KB   2.4MB/s   00:00
# text-26.tsv                                   100%   89KB   3.0MB/s   00:00
# text-112.tsv                                  100%   91KB   3.1MB/s   00:00
# text-106.tsv                                  100%   70KB   3.2MB/s   00:00
# anno-1.tsv                                    100%   14MB   7.8MB/s   00:01
# text-107.tsv                                  100%  105KB   5.6MB/s   00:00
# text-113.tsv                                  100%   93KB   4.5MB/s   00:00
# text-27.tsv                                   100%   77KB   3.9MB/s   00:00
# text-33.tsv                                   100%  134KB   5.5MB/s   00:00
# text-19.tsv                                   100%  121KB   4.4MB/s   00:00
# text-25.tsv                                   100%   86KB   3.5MB/s   00:00
# text-31.tsv                                   100%  100KB   3.7MB/s   00:00
# text-105.tsv                                  100%   49KB   3.0MB/s   00:00
# text-111.tsv                                  100%  101KB   3.8MB/s   00:00
# text-110.tsv                                  100%  125KB   4.6MB/s   00:00
# text-104.tsv                                  100%  100KB   4.7MB/s   00:00
# text-30.tsv                                   100%  102KB   2.8MB/s   00:00
# text-24.tsv                                   100%  111KB   4.0MB/s   00:00
# text-18.tsv                                   100%   42KB   1.7MB/s   00:00
# text-20.tsv                                   100%  141KB   3.2MB/s   00:00
# text-34.tsv                                   100%  119KB   5.5MB/s   00:00
# text-100.tsv                                  100%   58KB   3.0MB/s   00:00
# text-114.tsv                                  100%   26KB   1.5MB/s   00:00
# text-115.tsv                                  100%   58KB   2.1MB/s   00:00
# text-101.tsv                                  100%  124KB   4.9MB/s   00:00
# text-35.tsv                                   100%  112KB   5.1MB/s   00:00
# text-21.tsv                                   100%   58KB   3.0MB/s   00:00
# text-37.tsv                                   100%   85KB   3.9MB/s   00:00
# text-23.tsv                                   100%  171KB   3.4MB/s   00:00
# text-117.tsv                                  100%  104KB   4.5MB/s   00:00
# text-103.tsv                                  100%   89KB   4.4MB/s   00:00
# text-102.tsv                                  100%   87KB   4.0MB/s   00:00
# text-116.tsv                                  100%   55KB   3.0MB/s   00:00
# text-22.tsv                                   100%   56KB   3.0MB/s   00:00
# text-36.tsv                                   100%   95KB   4.2MB/s   00:00
# anno2node.tsv                                 100% 3976KB  13.2MB/s   00:00
# text-79.tsv                                   100%  147KB   7.5MB/s   00:00
# text-51.tsv                                   100%   58KB   4.1MB/s   00:00
# text-45.tsv                                   100%  204KB   8.0MB/s   00:00
# text-92.tsv                                   100%   87KB   5.5MB/s   00:00
# text-86.tsv                                   100%   71KB   3.9MB/s   00:00
# text-6.tsv                                    100%  101KB   6.0MB/s   00:00
# text-7.tsv                                    100%   90KB   4.2MB/s   00:00
# text-87.tsv                                   100%   53KB   2.8MB/s   00:00
# text-93.tsv                                   100%   65KB   2.9MB/s   00:00
# text-44.tsv                                   100%   26KB   3.1MB/s   00:00
# text-50.tsv                                   100%   35KB   2.1MB/s   00:00
# text-78.tsv                                   100%   27KB   2.7MB/s   00:00
# text-46.tsv                                   100%  197KB   6.5MB/s   00:00
# text-52.tsv                                   100%   33KB   2.4MB/s   00:00
# text-85.tsv                                   100%   55KB   2.2MB/s   00:00
# text-91.tsv                                   100%  104KB   4.3MB/s   00:00
# text-5.tsv                                    100%  147KB   5.0MB/s   00:00
# text-4.tsv                                    100%   88KB   4.7MB/s   00:00
# text-90.tsv                                   100%  104KB   5.5MB/s   00:00
# text-84.tsv                                   100%   67KB   3.4MB/s   00:00
# text-53.tsv                                   100%   32KB   2.0MB/s   00:00
# text-47.tsv                                   100%   39KB   2.4MB/s   00:00
# text-43.tsv                                   100%  100KB   2.9MB/s   00:00
# text-57.tsv                                   100%   65KB   4.6MB/s   00:00
# text-80.tsv                                   100%   85KB   4.5MB/s   00:00
# text-94.tsv                                   100%   58KB   2.3MB/s   00:00
# text-0.tsv                                    100%   67KB   3.8MB/s   00:00
# text-1.tsv                                    100%   64KB   3.3MB/s   00:00
# text-95.tsv                                   100%  102KB   4.2MB/s   00:00
# text-81.tsv                                   100%  223KB   6.3MB/s   00:00
# text-56.tsv                                   100%   36KB   2.6MB/s   00:00
# text-42.tsv                                   100%   94KB   4.4MB/s   00:00
# text-54.tsv                                   100%   39KB   1.9MB/s   00:00
# text-40.tsv                                   100%  246KB   6.9MB/s   00:00
# text-68.tsv                                   100%   26KB   2.7MB/s   00:00
# text-97.tsv                                   100%  108KB   4.8MB/s   00:00
# text-83.tsv                                   100%   73KB   3.5MB/s   00:00
# text-3.tsv                                    100% 6912   838.4KB/s   00:00
# text-2.tsv                                    100%  283KB   7.3MB/s   00:00
# text-82.tsv                                   100%   37KB   2.6MB/s   00:00
# text-96.tsv                                   100%   77KB   3.9MB/s   00:00
# text-69.tsv                                   100%   30KB   3.9MB/s   00:00
# text-41.tsv                                   100%   61KB   2.8MB/s   00:00
# text-55.tsv                                   100%  150KB   6.0MB/s   00:00
# text-58.tsv                                   100%  106KB   4.1MB/s   00:00
# text-70.tsv                                   100%   78KB   3.6MB/s   00:00
# text-64.tsv                                   100%   78KB   4.5MB/s   00:00
# text-65.tsv                                   100%   84KB   4.2MB/s   00:00
# text-71.tsv                                   100%   59KB   4.1MB/s   00:00
# text-59.tsv                                   100%   61KB   3.3MB/s   00:00
# text-67.tsv                                   100%   79KB   2.7MB/s   00:00
# text-73.tsv                                   100%   72KB   3.2MB/s   00:00
# text-98.tsv                                   100%   65KB   3.4MB/s   00:00
# text-99.tsv                                   100%   66KB   3.1MB/s   00:00
# text-72.tsv                                   100%   98KB   4.0MB/s   00:00
# text-66.tsv                                   100%   65KB   3.0MB/s   00:00
# text-62.tsv                                   100%   63KB   3.8MB/s   00:00
# text-76.tsv                                   100%   27KB   2.3MB/s   00:00
# text-89.tsv                                   100%  110KB   4.9MB/s   00:00
# text-9.tsv                                    100%   89KB   5.3MB/s   00:00
# text-8.tsv                                    100%   77KB   3.2MB/s   00:00
# text-88.tsv                                   100%   59KB   2.5MB/s   00:00
# text-77.tsv                                   100%   25KB   2.2MB/s   00:00
# text-63.tsv                                   100%  111KB   4.6MB/s   00:00
# text-75.tsv                                   100%   12KB   1.4MB/s   00:00
# text-61.tsv                                   100%   64KB   3.2MB/s   00:00
# text-49.tsv                                   100%   50KB   2.4MB/s   00:00
# inherited.txt                                 100%   75KB   3.9MB/s   00:00
# text-48.tsv                                   100%   32KB   3.0MB/s   00:00
# text-60.tsv                                   100%  118KB   4.8MB/s   00:00
# text-74.tsv                                   100%   21KB   2.4MB/s   00:00
# text-13.tsv                                   100%  142KB   4.6MB/s   00:00
# pos2node.tsv                                  100%   25MB  19.2MB/s   00:01
# text-12.tsv                                   100%  104KB   4.0MB/s   00:00
# text-38.tsv                                   100%   78KB   4.7MB/s   00:00
# text-10.tsv                                   100%   78KB   3.7MB/s   00:00
# text-11.tsv                                   100%  154KB   5.4MB/s   00:00
# text-39.tsv                                   100%   79KB   3.3MB/s   00:00
# text-15.tsv                                   100%   12KB   1.9MB/s   00:00
# text-29.tsv                                   100%   25KB   2.8MB/s   00:00
# text-109.tsv                                  100%  125KB   4.9MB/s   00:00
# text-108.tsv                                  100%   74KB   3.1MB/s   00:00
# text-28.tsv                                   100% 9988     1.4MB/s   00:00
# text-14.tsv                                   100%  177KB   5.6MB/s   00:00
# text-16.tsv                                   100%   37KB   2.3MB/s   00:00
# text-17.tsv                                   100%   88KB   3.0MB/s   00:00
